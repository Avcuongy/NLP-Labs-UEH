# %%
import pandas as pd

# %%
df1=pd.read_excel("/content/drive/MyDrive/NLP - Class_Dataset/G01.xlsx")

# %%
df2=pd.read_excel("/content/drive/MyDrive/NLP - Class_Dataset/G02.xlsx")

# %%
df3=pd.read_excel("/content/drive/MyDrive/NLP - Class_Dataset/G03.xlsx")

# %%
df4=pd.read_excel("/content/drive/MyDrive/NLP - Class_Dataset/G04.xlsx")

# %%
df5=pd.read_excel("/content/drive/MyDrive/NLP - Class_Dataset/G05.xlsx")

# %%
df6=pd.read_excel("/content/drive/MyDrive/NLP - Class_Dataset/G06.xlsx")

# %%
df7=pd.read_excel("/content/drive/MyDrive/NLP - Class_Dataset/G07.xlsx")

# %%
df8=pd.read_excel("/content/drive/MyDrive/NLP - Class_Dataset/G08.xlsx")

# %%
df9=pd.read_excel("/content/drive/MyDrive/NLP - Class_Dataset/G09.xlsx")

# %%
df10=pd.read_excel("/content/drive/MyDrive/NLP - Class_Dataset/G10.xlsx")

# %%
df11=pd.read_excel("/content/drive/MyDrive/NLP - Class_Dataset/G11.xlsx")

# %%
df=pd.merge(df1, df2, how="outer").merge(df3, how="outer").merge(df4, how="outer").merge(df5, how="outer").merge(df6, how="outer").merge(df7, how="outer").merge(df8, how="outer").merge(df9, how="outer").merge(df10, how="outer").merge(df11, how="outer")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       582 non-null    object
#  1   title    580 non-null    object
#  2   content  580 non-null    object
#  3   topic    582 non-null    object
# dtypes: object(4)
# memory usage: 18.3+ KB

# %%
df.head()
# Out:
#         id                                              title  \
# 0  G01_001  Amorim: 'Man Utd có thể thắng nhiều hơn nếu đá...
# 1  G01_002  Madam Pang đến Đại sứ quán Việt Nam tại Thái L...
# 2  G01_003             Ngày 'phán quyết' của bóng đá Malaysia
# 3  G01_004  Các HLV người Tây Ban Nha thống trị châu Âu nh...
# 4  G01_005                    Vì sao Djokovic chưa giải nghệ?
#
#                                              content     topic
# 0  Hệ thống 3-4-3 của Amorim gây tranh cãi từ khi...  Thể thao
# 1  Madam Pang gặp Đại sứ đặc mệnh toàn quyền Việt...  Thể thao
# 2  FAMnộp đơn kháng cáongày 14/10. Trước đó, vào ...  Thể thao
# 3  Pep Guardiola trao đổi với Bernardo Silva tron...  Thể thao
# 4  Djokovic cứu bóng ở trận gặp Bergs, trên sân T...  Thể thao

# %%
df=df.dropna(how="any")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 580 entries, 0 to 581
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       580 non-null    object
#  1   title    580 non-null    object
#  2   content  580 non-null    object
#  3   topic    580 non-null    object
# dtypes: object(4)
# memory usage: 22.7+ KB

# %%
df.join

# %%
combined_df = df.groupby('topic').agg({
    'id': lambda x: ', '.join(x),
    'title': lambda x: ' '.join(x),
    'content': lambda x: ' '.join(x)
}).reset_index()

display(combined_df)
# Out:
#                       topic  \
# 0                 Chính trị
# 1                   Du lịch
# 2                  Giáo dục
# 3                  Giải trí
# 4    Khoa học và công nghệ
# 5                Kinh doanh
# 6           Quan hệ quốc tế
# 7           Sức khoẻ - y tế
# 8                  Thể thao
# 9         Xã hội - Đời sống
# 10  môi trường và thiên tai
#
#                                                    id  \
# 0   G04_001, G04_002, G04_003, G04_004, G04_005, G...
# 1   G09_001, G09_002, G09_003, G09_004, G09_005, G...
# 2   G06_001, G06_002, G06_003, G06_004, G06_005, G...
# 3   G02_001, G02_002, G02_003, G02_004, G02_005, G...
# 4   G05_001, G05_002, G05_003, G05_004, G05_005, G...
# 5   G03_001, G03_003, G03_004, G03_007, G03_008, G...
# 6   G11_001, G11_002, G11_003, G11_004, G11_005, G...
# 7   G08_001, G08_002, G08_003, G08_004, G08_005, G...
# 8   G01_001, G01_002, G01_003, G01_004, G01_005, G...
# 9   G10_001, G10_002, G10_003, G10_004, G10_005, G...
# ...

# %%
pip install underthesea

# %%
import underthesea

# %%
for i in range(len(combined_df["title"])):
  combined_df.loc[i, "title"] = " | ".join(underthesea.word_tokenize(combined_df["title"][i]))

# %%
for i in range(len(combined_df["content"])):
  combined_df.loc[i, "content"] = " | ".join(underthesea.word_tokenize(combined_df["content"][i]))

# %%
display(combined_df)
# Out:
#                       topic  \
# 0                 Chính trị
# 1                   Du lịch
# 2                  Giáo dục
# 3                  Giải trí
# 4    Khoa học và công nghệ
# 5                Kinh doanh
# 6           Quan hệ quốc tế
# 7           Sức khoẻ - y tế
# 8                  Thể thao
# 9         Xã hội - Đời sống
# 10  môi trường và thiên tai
#
#                                                    id  \
# 0   G04_001, G04_002, G04_003, G04_004, G04_005, G...
# 1   G09_001, G09_002, G09_003, G09_004, G09_005, G...
# 2   G06_001, G06_002, G06_003, G06_004, G06_005, G...
# 3   G02_001, G02_002, G02_003, G02_004, G02_005, G...
# 4   G05_001, G05_002, G05_003, G05_004, G05_005, G...
# 5   G03_001, G03_003, G03_004, G03_007, G03_008, G...
# 6   G11_001, G11_002, G11_003, G11_004, G11_005, G...
# 7   G08_001, G08_002, G08_003, G08_004, G08_005, G...
# 8   G01_001, G01_002, G01_003, G01_004, G01_005, G...
# 9   G10_001, G10_002, G10_003, G10_004, G10_005, G...
# ...

# %% [markdown]
# 1. Tạo một bảng dữ liệu trong đó, mỗi từ là một feature, và giá trị của nó là số lần xuất hiện của nó. Có thể cộng cả content+title lại. Tiếp đến feed bảng dữ liệu này vào 3 mô hình học máy của scikit (Logistic, SVM, NaiveBayes)
#
# 2. Làm tương tự ở 1, nhưng bảng dữ liệu với số thuộc tính giảm sau khi loại các từ xuất hiện chung trong nhiều nhóm (có thể sử dụng set kết hợp với intersect - phép giao). Bảng features này có kích thước nhỏ hơn nhiều so với bảng 1.
#
# 3. Không tạo bảng features như 1 và 2 mà sử dụng kĩ thuật BoW (trong scikit, sử dụng CountVectorize)
#
# 4. Không tạo bảng feature như 2 và 2 mà sử dụng tfidf (TfidfVectorizer của scikit)
